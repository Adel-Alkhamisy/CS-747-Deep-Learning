# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir("/content/gdrive/My Drive/CS747_Assignment2")

# %%
# %ls
# Out:
# classifier.py                      download_data.sh
# colab_setup.ipynb                  kaggle_submission.py
# CS747_assignment2_description.pdf  Untitled0.ipynb
# CS747_Assignment2_part1.ipynb      voc_dataloader.py
# CS747_Assignment2_part2.ipynb

# %%
# !pip3 install torch torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import torch
a = torch.Tensor([1]).cuda()
print(a)
# Out:
# tensor([1.], device='cuda:0')
